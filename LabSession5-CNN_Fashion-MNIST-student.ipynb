# %% [markdown]
# # ELU 502 Deep learning -- Lab session 5
# Pierre-Henri Conze, François Rousseau, Ronan Fablet - session: 1h20 (17th april)+3h (20th april)

# %% [markdown]
# ### Objectives: perform classification on Fashion-MNIST dataset using multiple layer perceptrons, convolutional neural networks, data augmentation and transfer learning to obtain the best classification results as possible!

# %% [markdown]
# First, download and read the Fashion-MNIST data.

# %%
# %matplotlib inline
import keras
from keras.datasets import fashion_mnist

(x_trainD, y_train), (x_testD, y_test) = fashion_mnist.load_data()

# %% [markdown]
# ### Part 1 - Data management and visualization

# %% [markdown]
# #### 1) Fashion-MNIST is a dataset consisting of a training set of A examples and a test set of B examples. Each example is a CxC grayscale image, associated with a label from D classes. What are the values for A, B, C and D?

# %%
import numpy as np

A=len(x_trainD)
B=len(x_testD)
C=len(x_trainD[0])
D=len(np.unique(y_train))
print("A: %i ; B: %i ; C: %i ; D: %i"  %(A,B,C,D))
# Out:
# A: 60000 ; B: 10000 ; C: 28 ; D: 10

# %% [markdown]
# Each training/test sample is assigned to one of the following labels:
# 0	T-shirt
# 1	Trouser
# 2	Pullover
# 3	Dress
# 4	Coat
# 5	Sandal
# 6	Shirt
# 7	Sneaker
# 8	Bag
# 9	Ankle boot

# %%
num_classes = D
class_names = ['tshirt', 'trouser', 'pullover', 'dress', 'coat', 'sandal', 'shirt', 'sneaker', 'bag', 'boot']

# %% [markdown]
# #### 2) Visualize one example per class among the training dataset:

# %%
import matplotlib.pyplot as plt

for i in range(num_classes):
    plt.subplot(2, num_classes/2, i + 1)
    index=np.where(y_train == i)[0][5]
    plt.imshow(x_trainD[index,:,:], cmap=plt.cm.gray_r, interpolation='nearest')
    plt.title('Training: %s' % class_names[i])
plt.subplots_adjust(right=3,top=2)
plt.show()

# %% [markdown]
# ### Part 2 - Multi-layer perceptrons

# %% [markdown]
# #### 3) Define a simple Keras multi-layer perceptron (MLP) architecture using Sequential API and containing 3 dense layers: 2 dense layers with 512 units and ReLU activation followed by 1 dense layer for softmax regression. Use your model to get first classification results on Fashion MNIST.

# %%
num_classes = D

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import RMSprop

# %%
#data formating

x_train = x_trainD.astype(float)/255
x_test = x_testD.astype(float)/255


z_train=keras.utils.to_categorical(y_train,num_classes)
z_test=keras.utils.to_categorical(y_test,num_classes)

x_train_flat = x_train.reshape(A,C*C)
x_test_flat = x_test.reshape(B,C*C)

# %%
mlp_1 = Sequential()

mlp_1.add(Dense(units=512, input_shape=(C*C,),activation="relu"))
mlp_1.add(Dense(units=512,activation="relu"))
mlp_1.add(Dense(10, activation="softmax"))

mlp_1.summary()

mlp_1.compile(RMSprop(), 'categorical_crossentropy', metrics=['accuracy'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_100 (Dense)            (None, 512)               401920
# _________________________________________________________________
# dense_101 (Dense)            (None, 512)               262656
# _________________________________________________________________
# dense_102 (Dense)            (None, 10)                5130
# =================================================================
# Total params: 669,706
# Trainable params: 669,706
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 128
epochs = 20

hist_mlp_1 = mlp_1.fit(x_train_flat, z_train, validation_data=(x_test_flat,z_test), epochs=epochs, batch_size=batch_size, verbose=2)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
#  - 3s - loss: 0.5388 - acc: 0.8019 - val_loss: 0.4520 - val_acc: 0.8351
# Epoch 2/20
#  - 2s - loss: 0.3746 - acc: 0.8602 - val_loss: 0.3793 - val_acc: 0.8633
# Epoch 3/20
#  - 2s - loss: 0.3378 - acc: 0.8751 - val_loss: 0.4109 - val_acc: 0.8529
# Epoch 4/20
#  - 1s - loss: 0.3117 - acc: 0.8855 - val_loss: 0.3980 - val_acc: 0.8614
# Epoch 5/20
#  - 1s - loss: 0.2956 - acc: 0.8901 - val_loss: 0.3838 - val_acc: 0.8704
# Epoch 6/20
#  - 1s - loss: 0.2821 - acc: 0.8965 - val_loss: 0.3839 - val_acc: 0.8729
# Epoch 7/20
#  - 1s - loss: 0.2700 - acc: 0.9003 - val_loss: 0.4340 - val_acc: 0.8664
# Epoch 8/20
#  - 1s - loss: 0.2599 - acc: 0.9061 - val_loss: 0.3627 - val_acc: 0.8836
# Epoch 9/20
#  - 2s - loss: 0.2511 - acc: 0.9068 - val_loss: 0.4265 - val_acc: 0.8638
# Epoch 10/20
#  - 1s - loss: 0.2459 - acc: 0.9093 - val_loss: 0.4116 - val_acc: 0.8831
# Epoch 11/20
#  - 1s - loss: 0.2381 - acc: 0.9107 - val_loss: 0.3880 - val_acc: 0.8851
# Epoch 12/20
#  - 1s - loss: 0.2345 - acc: 0.9144 - val_loss: 0.3778 - val_acc: 0.8847
# Epoch 13/20
#  - 1s - loss: 0.2287 - acc: 0.9159 - val_loss: 0.3676 - val_acc: 0.8857
# Epoch 14/20
#  - 2s - loss: 0.2236 - acc: 0.9171 - val_loss: 0.4472 - val_acc: 0.8799
# Epoch 15/20
#  - 2s - loss: 0.2229 - acc: 0.9199 - val_loss: 0.3813 - val_acc: 0.8895
# Epoch 16/20
#  - 1s - loss: 0.2159 - acc: 0.9219 - val_loss: 0.4468 - val_acc: 0.8765
# Epoch 17/20
#  - 1s - loss: 0.2129 - acc: 0.9223 - val_loss: 0.4294 - val_acc: 0.8857
# Epoch 18/20
#  - 1s - loss: 0.2043 - acc: 0.9256 - val_loss: 0.4733 - val_acc: 0.8749
# Epoch 19/20
#  - 1s - loss: 0.2053 - acc: 0.9260 - val_loss: 0.4607 - val_acc: 0.8831
# Epoch 20/20
#  - 2s - loss: 0.2016 - acc: 0.9257 - val_loss: 0.4238 - val_acc: 0.8866

# %% [markdown]
# #### 4) Define a generic function evaluate_model() able to:
# - plot the evolution of accuracy for both training and testing data with respect to the epochs
# - compute final test loss and accuracy.
#
# Use this function to assess the performance of the previously defined model.

# %%
def evaluate_model(model,history,x_eval,z_eval):
    
    # list all data in history
    print(history.history.keys())

    #Visualize history (loss vs epochs)
    plt.figure()
    plt.subplot(121)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')  
    plt.xlabel('epochs')
    plt.legend(['train','val'], loc='upper left')
    plt.subplot(122)
    plt.plot(history.history['acc'])
    plt.plot(history.history['val_acc'])
    plt.title('model accuracy')
    plt.ylabel('acc')  
    plt.xlabel('epochs')
    plt.legend(['train','val'], loc='upper left')
    plt.subplots_adjust(right=3,top=2)
    plt.show()
    
    score = model.evaluate(x_eval, z_eval, verbose=0)
    print('Test loss:', score[0])
    print('Test accuracy:', score[1])

# %%
evaluate_model(mlp_1,hist_mlp_1,x_test_flat,z_test)
# Out:
# ['acc', 'loss', 'val_acc', 'val_loss']
# ('Test loss:', 0.42383191273808479)
# ('Test accuracy:', 0.88660000000000005)

# %% [markdown]
# ##### Comments: Accuracy of 88.66% is not bad but we see the generalisation error from 3~4 epochs

# %% [markdown]
# #### 5) Define a deeper multi-layer perceptron (MLP) architecture to outperform the previously obtained classification results.
# Use evaluate_model() to provide the evaluation and comment the performance.

# %%
mlp_2 = Sequential()

mlp_2.add(Dense(units=512, input_shape=(C*C,),activation="relu"))
mlp_2.add(Dense(units=512,activation="relu"))
mlp_2.add(Dense(units=64,activation="relu"))
mlp_2.add(Dense(10, activation="softmax"))

mlp_2.summary()

mlp_2.compile(RMSprop(), 'categorical_crossentropy', metrics=['accuracy'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_96 (Dense)             (None, 512)               401920
# _________________________________________________________________
# dense_97 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_98 (Dense)             (None, 64)                32832
# _________________________________________________________________
# dense_99 (Dense)             (None, 10)                650
# =================================================================
# Total params: 698,058
# Trainable params: 698,058
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 128
epochs = 20

hist_mlp_2 = mlp_2.fit(x_train_flat, z_train, validation_data=(x_test_flat,z_test), epochs=epochs, batch_size=batch_size, verbose=2)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
#  - 3s - loss: 0.5607 - acc: 0.7936 - val_loss: 0.4333 - val_acc: 0.8399
# Epoch 2/20
#  - 2s - loss: 0.3831 - acc: 0.8576 - val_loss: 0.3973 - val_acc: 0.8592
# Epoch 3/20
#  - 2s - loss: 0.3419 - acc: 0.8741 - val_loss: 0.4052 - val_acc: 0.8500
# Epoch 4/20
#  - 1s - loss: 0.3143 - acc: 0.8850 - val_loss: 0.3437 - val_acc: 0.8764
# Epoch 5/20
#  - 1s - loss: 0.2958 - acc: 0.8915 - val_loss: 0.3713 - val_acc: 0.8696
# Epoch 6/20
#  - 2s - loss: 0.2841 - acc: 0.8948 - val_loss: 0.4073 - val_acc: 0.8630
# Epoch 7/20
#  - 2s - loss: 0.2733 - acc: 0.8996 - val_loss: 0.3674 - val_acc: 0.8734
# Epoch 8/20
#  - 1s - loss: 0.2642 - acc: 0.9020 - val_loss: 0.4359 - val_acc: 0.8605
# Epoch 9/20
#  - 2s - loss: 0.2571 - acc: 0.9052 - val_loss: 0.3609 - val_acc: 0.8795
# Epoch 10/20
#  - 2s - loss: 0.2511 - acc: 0.9078 - val_loss: 0.3870 - val_acc: 0.8748
# Epoch 11/20
#  - 2s - loss: 0.2476 - acc: 0.9094 - val_loss: 0.3776 - val_acc: 0.8887
# Epoch 12/20
#  - 1s - loss: 0.2441 - acc: 0.9113 - val_loss: 0.3612 - val_acc: 0.8898
# Epoch 13/20
#  - 1s - loss: 0.2388 - acc: 0.9125 - val_loss: 0.4067 - val_acc: 0.8645
# Epoch 14/20
#  - 1s - loss: 0.2312 - acc: 0.9153 - val_loss: 0.3809 - val_acc: 0.8710
# Epoch 15/20
#  - 1s - loss: 0.2317 - acc: 0.9172 - val_loss: 0.4429 - val_acc: 0.8781
# Epoch 16/20
#  - 1s - loss: 0.2312 - acc: 0.9177 - val_loss: 0.4094 - val_acc: 0.8838
# Epoch 17/20
#  - 2s - loss: 0.2278 - acc: 0.9199 - val_loss: 0.3981 - val_acc: 0.8837
# Epoch 18/20
#  - 1s - loss: 0.2228 - acc: 0.9209 - val_loss: 0.4832 - val_acc: 0.8807
# Epoch 19/20
#  - 1s - loss: 0.2210 - acc: 0.9215 - val_loss: 0.4896 - val_acc: 0.8718
# Epoch 20/20
#  - 1s - loss: 0.2169 - acc: 0.9222 - val_loss: 0.4087 - val_acc: 0.8921

# %%
evaluate_model(mlp_2,hist_mlp_2,x_test_flat,z_test)
# Out:
# ['acc', 'loss', 'val_acc', 'val_loss']
# ('Test loss:', 0.40869325551986696)
# ('Test accuracy:', 0.8921)

# %% [markdown]
# ##### Conclusion: accuracy (89.21%) a bit better but not much. Maybe the limit of MLP ?
# But we saw that there is a lot of randomness, sometimes we got 89% accuracy with mlp_1 and much less with mlp_2

# %% [markdown]
# ### Part 3 - Convolutional neural networks

# %% [markdown]
# ##### 6) Define a simple Keras convolutional neural network (CNN) architecture using Sequential API and containing the following layers : 1 convolution layer using Conv2D and 32 filters, 1 max-polling layer using MaxPooling2D, 2 dense layers using ReLU and softmax activations respectively. Use this model to get classification results (use evaluate_model() as previously) and compared them to MLP results.

# %%
# build 4D tensors
x_train_cnn = x_train.reshape(A, C, C, 1)
x_test_cnn = x_test.reshape(B, C, C, 1)

input_shape = (C, C, 1)

# %%
from keras.layers import Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K

# %%
cnn_1 = Sequential()

cnn_1.add(Conv2D(32, (3,3), activation="relu", input_shape = input_shape, padding="SAME"))
cnn_1.add(MaxPooling2D())

cnn_1.add(Flatten())

cnn_1.add(Dense(units=6272,activation="relu"))
cnn_1.add(Dense(units=num_classes, activation="softmax"))

cnn_1.summary()

cnn_1.compile(RMSprop(), 'categorical_crossentropy', metrics=['accuracy'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_13 (Conv2D)           (None, 28, 28, 32)        320
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 14, 14, 32)        0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dense_83 (Dense)             (None, 6272)              39344256
# _________________________________________________________________
# dense_84 (Dense)             (None, 10)                62730
# =================================================================
# Total params: 39,407,306
# Trainable params: 39,407,306
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 128
epochs = 12

hist_cnn_1 = cnn_1.fit(x_train_cnn, z_train, validation_data=(x_test_cnn,z_test), epochs=epochs, batch_size=batch_size, verbose=2)
evaluate_model(cnn_1,hist_cnn_1,x_test_cnn,z_test)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/12
#  - 17s - loss: 0.4547 - acc: 0.8540 - val_loss: 0.2827 - val_acc: 0.8982
# Epoch 2/12
#  - 16s - loss: 0.2336 - acc: 0.9141 - val_loss: 0.2974 - val_acc: 0.8910
# Epoch 3/12
#  - 16s - loss: 0.1804 - acc: 0.9345 - val_loss: 0.2581 - val_acc: 0.9125
# Epoch 4/12
#  - 16s - loss: 0.1418 - acc: 0.9483 - val_loss: 0.2981 - val_acc: 0.9118
# Epoch 5/12
#  - 16s - loss: 0.1113 - acc: 0.9597 - val_loss: 0.3150 - val_acc: 0.9157
# Epoch 6/12
#  - 16s - loss: 0.0890 - acc: 0.9680 - val_loss: 0.3320 - val_acc: 0.9163
# Epoch 7/12
#  - 16s - loss: 0.0727 - acc: 0.9751 - val_loss: 0.3356 - val_acc: 0.9185
# Epoch 8/12
#  - 16s - loss: 0.0586 - acc: 0.9791 - val_loss: 0.3842 - val_acc: 0.9131
# Epoch 9/12
#  - 16s - loss: 0.0488 - acc: 0.9831 - val_loss: 0.3959 - val_acc: 0.9109
# Epoch 10/12
#  - 16s - loss: 0.0411 - acc: 0.9855 - val_loss: 0.6122 - val_acc: 0.8854
# Epoch 11/12
#  - 16s - loss: 0.0351 - acc: 0.9878 - val_loss: 0.5127 - val_acc: 0.9168
# Epoch 12/12
#  - 16s - loss: 0.0303 - acc: 0.9903 - val_loss: 0.4612 - val_acc: 0.9140
# ['acc', 'loss', 'val_acc', 'val_loss']
# ('Test loss:', 0.46124776117354632)
# ('Test accuracy:', 0.91400000000000003)

# %% [markdown]
# ###### Comments: The accuracy (91.4%) is better than the MLPs ones.
# There is a lot of paramaters (almost 40millions because of the fully connected layer), we do overfitting quickly as we see the generalization error early on

# %% [markdown]
# #### 7) As for MLP, define a deeper CNN architecture to outperform the previously obtained classification results. What are your conclusions?

# %%
cnn_2 = Sequential()

cnn_2.add(Conv2D(64, (5, 5), input_shape=input_shape, padding='same',activation='relu'))
cnn_2.add(MaxPooling2D(pool_size=(2, 2),padding='same'))

cnn_2.add(Dropout(0.3))

cnn_2.add(Conv2D(64, (3, 3), padding='same',activation='relu'))
cnn_2.add(MaxPooling2D(pool_size=(2, 2),padding='same'))

cnn_2.add(Dropout(0.3))

cnn_2.add(Flatten())
    
cnn_2.add(Dense(256, activation='relu'))

cnn_2.add(Dropout(0.1))

cnn_2.add(Dense(64, activation='relu'))
    
cnn_2.add(Dense(num_classes, activation='softmax'))

cnn_2.compile(RMSprop(),'categorical_crossentropy', metrics=['accuracy'])

cnn_2.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_14 (Conv2D)           (None, 28, 28, 64)        1664
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 14, 14, 64)        36928
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 7, 7, 64)          0
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# dense_85 (Dense)             (None, 256)               803072
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_86 (Dense)             (None, 64)                16448
# _________________________________________________________________
# dense_87 (Dense)             (None, 10)                650
# =================================================================
# Total params: 858,762
# Trainable params: 858,762
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 128
epochs = 30

hist_cnn_2 = cnn_2.fit(x_train_cnn, z_train, validation_data=(x_test_cnn,z_test), epochs=epochs, batch_size=batch_size, verbose=2)
evaluate_model(cnn_2,hist_cnn_2,x_test_cnn,z_test)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/30
#  - 6s - loss: 0.5468 - acc: 0.7984 - val_loss: 0.3840 - val_acc: 0.8570
# Epoch 2/30
#  - 5s - loss: 0.3296 - acc: 0.8796 - val_loss: 0.3171 - val_acc: 0.8837
# Epoch 3/30
#  - 6s - loss: 0.2824 - acc: 0.8961 - val_loss: 0.3069 - val_acc: 0.8881
# Epoch 4/30
#  - 5s - loss: 0.2591 - acc: 0.9039 - val_loss: 0.2692 - val_acc: 0.9032
# Epoch 5/30
#  - 6s - loss: 0.2422 - acc: 0.9111 - val_loss: 0.2529 - val_acc: 0.9077
# Epoch 6/30
#  - 6s - loss: 0.2276 - acc: 0.9161 - val_loss: 0.2533 - val_acc: 0.9073
# Epoch 7/30
#  - 5s - loss: 0.2158 - acc: 0.9202 - val_loss: 0.2364 - val_acc: 0.9178
# Epoch 8/30
#  - 5s - loss: 0.2056 - acc: 0.9238 - val_loss: 0.2414 - val_acc: 0.9130
# Epoch 9/30
#  - 6s - loss: 0.2000 - acc: 0.9259 - val_loss: 0.2382 - val_acc: 0.9145
# Epoch 10/30
#  - 5s - loss: 0.1928 - acc: 0.9292 - val_loss: 0.2269 - val_acc: 0.9201
# Epoch 11/30
#  - 5s - loss: 0.1872 - acc: 0.9315 - val_loss: 0.2222 - val_acc: 0.9204
# Epoch 12/30
#  - 6s - loss: 0.1824 - acc: 0.9323 - val_loss: 0.2308 - val_acc: 0.9170
# Epoch 13/30
#  - 5s - loss: 0.1782 - acc: 0.9341 - val_loss: 0.2295 - val_acc: 0.9171
# Epoch 14/30
#  - 5s - loss: 0.1740 - acc: 0.9365 - val_loss: 0.2278 - val_acc: 0.9207
# Epoch 15/30
#  - 5s - loss: 0.1729 - acc: 0.9370 - val_loss: 0.2265 - val_acc: 0.9205
# Epoch 16/30
#  - 5s - loss: 0.1672 - acc: 0.9388 - val_loss: 0.2376 - val_acc: 0.9166
# Epoch 17/30
#  - 6s - loss: 0.1643 - acc: 0.9394 - val_loss: 0.2316 - val_acc: 0.9208
# Epoch 18/30
#  - 5s - loss: 0.1641 - acc: 0.9399 - val_loss: 0.2351 - val_acc: 0.9200
# Epoch 19/30
#  - 5s - loss: 0.1601 - acc: 0.9427 - val_loss: 0.2332 - val_acc: 0.9175
# Epoch 20/30
#  - 5s - loss: 0.1603 - acc: 0.9412 - val_loss: 0.2246 - val_acc: 0.9197
# Epoch 21/30
#  - 6s - loss: 0.1563 - acc: 0.9424 - val_loss: 0.2307 - val_acc: 0.9200
# Epoch 22/30
#  - 5s - loss: 0.1566 - acc: 0.9434 - val_loss: 0.2486 - val_acc: 0.9174
# Epoch 23/30
#  - 5s - loss: 0.1559 - acc: 0.9442 - val_loss: 0.2359 - val_acc: 0.9223
# Epoch 24/30
#  - 6s - loss: 0.1534 - acc: 0.9437 - val_loss: 0.2229 - val_acc: 0.9248
# Epoch 25/30
#  - 5s - loss: 0.1524 - acc: 0.9449 - val_loss: 0.2372 - val_acc: 0.9200
# Epoch 26/30
#  - 5s - loss: 0.1520 - acc: 0.9442 - val_loss: 0.2366 - val_acc: 0.9190
# Epoch 27/30
#  - 5s - loss: 0.1496 - acc: 0.9454 - val_loss: 0.2323 - val_acc: 0.9202
# Epoch 28/30
#  - 5s - loss: 0.1543 - acc: 0.9440 - val_loss: 0.2370 - val_acc: 0.9253
# Epoch 29/30
#  - 5s - loss: 0.1503 - acc: 0.9457 - val_loss: 0.2354 - val_acc: 0.9196
# Epoch 30/30
#  - 5s - loss: 0.1499 - acc: 0.9461 - val_loss: 0.2350 - val_acc: 0.9189
# ['acc', 'loss', 'val_acc', 'val_loss']
# ('Test loss:', 0.23503023082613944)
# ('Test accuracy:', 0.91890000000000005)

# %% [markdown]
# ##### Comments: We increased the accuracy a bit (91.89%). With less parameters and dropout we saw less generalization error with 12 epochs, so we try with a greater number of epochs.
# Because of the Dropouts the training is a lot slower, the accuracy on the training set is increasing slowly

# %% [markdown]
# ### Part 4 - Visualize wrongly predictions

# %% [markdown]
# #### 8) Create a function visualize_wrongly_predictions() able to show wrong prediction for each class for a given model as input. Use this function for each of the 4 previouly trained models (2 MLP, 2 CNN).

# %%
def visualize_wrongly_predictions(model,x_test):
    z_predict= model.predict(x_test,batch_size)
    y_predict=[np.argmax(i) for i in z_predict]
    y_false = y_test-y_predict
    y_false_index = np.where(y_false !=0)[0]
    
    
    c=0
    for i in y_false_index[:10]:
        plt.subplot(2, 5, c + 1)
        plt.axis('off')
        plt.imshow(x_testD[i], cmap=plt.cm.gray_r, interpolation='nearest')
        plt.title('Num:%i (True: %s , Pred: %s)' % (i,class_names[y_test[i]], class_names[y_predict[i]]))
        c+=1
    plt.subplots_adjust(right=3,top =1)
    plt.show()

# %%
print("Wrong predictions of mlp_1")
visualize_wrongly_predictions(mlp_1,x_test_flat)
print("Wrong predictions of mlp_2")
visualize_wrongly_predictions(mlp_2,x_test_flat)
# Out:
# Wrong predictions of mlp_1
# Wrong predictions of mlp_2

# %%
print("Wrong predictions of cnn_1")
visualize_wrongly_predictions(cnn_1,x_test_cnn)
print("Wrong predictions of cnn_2")
visualize_wrongly_predictions(cnn_2,x_test_cnn)
# Out:
# Wrong predictions of cnn_1
# Wrong predictions of cnn_2

# %% [markdown]
# ##### Comments: We see that the MLPs share errors in common and the CNNs ones also between them but less with the MLP's wrong predictions. The wrong classes predicted are always the same

# %% [markdown]
# #### 9) Using the code given below, create a function visualize_confusion_matrix() able to display the confusion matrix  for a given model as input. Use this function for each of the 4 previouly trained models (2 MLP, 2 CNN). What is the most common confusion?

# %%
from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        #print("Normalized confusion matrix")
    #else:
        #print('Confusion matrix, without normalization')

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
def visualize_confusion_matrix(model,x_test,y_test,title):
    z_pred= model.predict(x_test)
    y_pred=[np.argmax(i) for i in z_pred]
    cm = confusion_matrix(y_test, y_pred)
    np.set_printoptions(precision=2)
    plt.figure()
    plot_confusion_matrix(cm, class_names,normalize=True, title=title)

# %%
visualize_confusion_matrix(mlp_1,x_test_flat,y_test,"Normalized Confusion matrix of mlp_1")
visualize_confusion_matrix(mlp_2,x_test_flat,y_test,"Normalized Confusion matrix of mlp_2")

# %%
visualize_confusion_matrix(cnn_1,x_test_cnn,y_test,"Normalized Confusion matrix of cnn_1")
visualize_confusion_matrix(cnn_2,x_test_cnn,y_test,"Normalized Confusion matrix of cnn_2")

# %% [markdown]
# ##### Most common confusion: With the MLP networks the most common confusions are pullover et shirt which are mistaken for coat and t-shirt. With the mlp_2 this confusions are a bit less common. With the CNN networks there is only one class wich is more inaccurate than the others, it's the shirt wich is mistaken mostly for t-shirt. But pullover is no longer a problem for these networks

# %% [markdown]
# ##### Conclusion:

# %% [markdown]
# ### Part 5 - Data augmentation

# %% [markdown]
# #### 10) Based on the documentation (https://keras.io/preprocessing/image/), train one of your CNN architecture using data augmentation and conclude on the used of augmented data.

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rotation_range=8,
    width_shift_range=0.08,
    height_shift_range=0.08,
    shear_range=0.3, 
    zoom_range=0.08)

data_aug = datagen.flow(x_train_cnn,z_train,batch_size=1)
#data_aug is a list of 60000 tuples (augmented image,class in one-hot-vector)
"""
x_train_gen=[]
z_train_gen=[]
for data_img in data_aug:
    x_train_gen.append(data_img[0])
    z_train_gen.append(data_img[1])
print(x_train_gen.shape())
"""
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-220-470c58f55ca2> in <module>()
#      13 x_train_gen=[]
#      14 z_train_gen=[]
# ---> 15 for data_img in data_aug:
#      16     x_train_gen.append(data_img[0])
#      17     z_train_gen.append(data_img[1])
#
# /opt/campux/virtualenv/deeplearning/lib/python2.7/site-packages/keras/preprocessing/image.pyc in next(self)
#     900         # The transformation of images is not under thread lock
#     901         # so it can be done in parallel
# --> 902         return self._get_batches_of_transformed_samples(index_array)
#     903
#     904
#
# /opt/campux/virtualenv/deeplearning/lib/python2.7/site-packages/keras/preprocessing/image.pyc in _get_batches_of_transformed_samples(self, index_array)
#     872         for i, j in enumerate(index_array):
#     873             x = self.x[j]
# --> 874             x = self.image_data_generator.random_transform(x.astype(K.floatx()))
#     875             x = self.image_data_generator.standardize(x)
#     876             batch_x[i] = x
#
# /opt/campux/virtualenv/deeplearning/lib/python2.7/site-packages/keras/preprocessing/image.pyc in random_transform(self, x, seed)
#     634             transform_matrix = transform_matrix_offset_center(transform_matrix, h, w)
#     635             x = apply_transform(x, transform_matrix, img_channel_axis,
# --> 636                                 fill_mode=self.fill_mode, cval=self.cval)
#     637
#     638         if self.channel_shift_range != 0:
#
# /opt/campux/virtualenv/deeplearning/lib/python2.7/site-packages/keras/preprocessing/image.pyc in apply_transform(x, transform_matrix, channel_axis, fill_mode, cval)
#     222         order=0,
#     223         mode=fill_mode,
# --> 224         cval=cval) for x_channel in x]
#     225     x = np.stack(channel_images, axis=0)
#     226     x = np.rollaxis(x, 0, channel_axis + 1)
#
# /opt/campux/virtualenv/deeplearning/lib/python2.7/site-packages/scipy/ndimage/interpolation.pyc in affine_transform(input, matrix, offset, output_shape, output, order, mode, cval, prefilter)
#     469         matrix = matrix.copy()
#     470     offset = _ni_support._normalize_sequence(offset, input.ndim)
# --> 471     offset = numpy.asarray(offset, dtype=numpy.float64)
#     472     if offset.ndim != 1 or offset.shape[0] < 1:
#     473         raise RuntimeError('no proper offset provided')
#
# /opt/campux/virtualenv/deeplearning/lib/python2.7/site-packages/numpy/core/numeric.pyc in asarray(a, dtype, order)
#     529
#     530     """
# --> 531     return array(a, dtype, copy=False, order=order)
#     532
#     533
#
# KeyboardInterrupt:

# %%
hist_cnn_2_aug=cnn_2.fit_generator(x_train_cnn,z_train, validation_data=(x_test_cnn,z_test), epochs=epochs, verbose=2)
# Out:
# Epoch 1/20
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-158-2e8cd817c917> in <module>()
# ----> 1 hist_cnn_2_aug=cnn_2.fit_generator(x_train_cnn,z_train, validation_data=(x_test_cnn,z_test), epochs=epochs, verbose=2)
#
# /opt/campux/virtualenv/deeplearning/lib/python2.7/site-packages/keras/legacy/interfaces.pyc in wrapper(*args, **kwargs)
#      85                 warnings.warn('Update your `' + object_name +
#      86                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 87             return func(*args, **kwargs)
#      88         wrapper._original_function = func
#      89         return wrapper
#
# /opt/campux/virtualenv/deeplearning/lib/python2.7/site-packages/keras/models.pyc in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1225                                         use_multiprocessing=use_multiprocessing,
#    1226                                         shuffle=shuffle,
# -> 1227                                         initial_epoch=initial_epoch)
#    1228
#    1229     @interfaces.legacy_generator_methods_support
#
# /opt/campux/virtualenv/deeplearning/lib/python2.7/site-packages/keras/legacy/interfaces.pyc in wrapper(*args, **kwargs)
#      85                 warnings.warn('Update your `' + object_name +
#      86                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 87             return func(*args, **kwargs)
#      88         wrapper._original_function = func
#      89         return wrapper
#
# /opt/campux/virtualenv/deeplearning/lib/python2.7/site-packages/keras/engine/training.pyc in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2112                 steps_done = 0
#    2113                 batch_index = 0
# -> 2114                 while steps_done < steps_per_epoch:
#    2115                     generator_output = next(output_generator)
#    2116
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %% [markdown]
# Comments: #todo

# %% [markdown]
# ### Part 6 - Transfer learning from VGG16 trained on ImageNet

# %% [markdown]
# Transfer learning, is a research problem in machine learning that focuses on storing knowledge gained while solving one problem and applying it to a different but related problem.
#
# In this part, you will do fine tuning on a pre-trained network. Fine-tuning consists in starting from a trained network, then re-training it on a new dataset using very small weight updates. To do so, you need to load a pre-trained model, add a dense classifier to compute the output, and then to freeze the weights of the pre-trained model (https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html).

# %% [markdown]
# #### 11) Exploit an architecture already trained on ImageNet (https://keras.io/applications) to improve the classification results on Fashion-MNIST.

# %%
from keras import applications
from skimage.transform import resize

# to do

# %%
# to do

# %% [markdown]
# Conclusion: #todo

# %% [markdown]
# #### 12) Challenge: the first 3 teams in terms of overall test accuracy results (whatever the methodology used) will obtain bonus points!

# %% [markdown]
# Best accuracy reached: #todo

# %% [markdown]
# Conclusions: #todo
