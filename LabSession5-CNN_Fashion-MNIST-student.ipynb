# %% [markdown]
# # ELU 502 Deep learning -- Lab session 5
# Pierre-Henri Conze, François Rousseau, Ronan Fablet - session: 1h20 (17th april)+3h (20th april)

# %% [markdown]
# ### Objectives: perform classification on Fashion-MNIST dataset using multiple layer perceptrons, convolutional neural networks, data augmentation and transfer learning to obtain the best classification results as possible!

# %% [markdown]
# First, download and read the Fashion-MNIST data.

# %%
# %matplotlib inline
import keras
from keras.datasets import fashion_mnist

(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# %% [markdown]
# ### Part 1 - Data management and visualization

# %% [markdown]
# #### 1) Fashion-MNIST is a dataset consisting of a training set of A examples and a test set of B examples. Each example is a CxC grayscale image, associated with a label from D classes. What are the values for A, B, C and D?

# %%
import numpy as np

A=len(x_train)
B=len(x_test)
C=len(x_train[0])
D=len(np.unique(y_train))
print("A: %i ; B: %i ; C: %i ; D: %i"  %(A,B,C,D))
# Out:
# A: 60000 ; B: 10000 ; C: 28 ; D: 10

# %% [markdown]
# Each training/test sample is assigned to one of the following labels:
# 0	T-shirt
# 1	Trouser
# 2	Pullover
# 3	Dress
# 4	Coat
# 5	Sandal
# 6	Shirt
# 7	Sneaker
# 8	Bag
# 9	Ankle boot

# %%
num_classes = D
class_names = ['tshirt', 'trouser', 'pullover', 'dress', 'coat', 'sandal', 'shirt', 'sneaker', 'bag', 'boot']

# %% [markdown]
# #### 2) Visualize one example per class among the training dataset:

# %%
import matplotlib.pyplot as plt

for i in range(num_classes):
    plt.subplot(2, num_classes/2, i + 1)
    index=np.where(y_train == i)[0][5]
    plt.imshow(x_train[index,:,:], cmap=plt.cm.gray_r, interpolation='nearest')
    plt.title('Training: %s' % class_names[i])
plt.subplots_adjust(right=3,top=2)
plt.show()

# %% [markdown]
# ### Part 2 - Multi-layer perceptrons

# %% [markdown]
# #### 3) Define a simple Keras multi-layer perceptron (MLP) architecture using Sequential API and containing 3 dense layers: 2 dense layers with 512 units and ReLU activation followed by 1 dense layer for softmax regression. Use your model to get first classification results on Fashion MNIST.

# %%
num_classes = D

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import RMSprop

# %%
#data formating

x_train = x_train.astype(float)/255
x_test = x_test.astype(float)/255


z_train=keras.utils.to_categorical(y_train,num_classes)
z_test=keras.utils.to_categorical(y_test,num_classes)

x_train_flat = x_train.reshape(A,C*C)
x_test_flat = x_test.reshape(B,C*C)

# %%
mlp_1 = Sequential()

mlp_1.add(Dense(units=512, input_shape=(C*C,),activation="relu"))
mlp_1.add(Dense(units=512,activation="relu"))
mlp_1.add(Dense(10, activation="softmax"))

mlp_1.summary()

mlp_1.compile(RMSprop(), 'categorical_crossentropy', metrics=['accuracy'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_22 (Dense)             (None, 512)               401920
# _________________________________________________________________
# dense_23 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_24 (Dense)             (None, 10)                5130
# =================================================================
# Total params: 669,706
# Trainable params: 669,706
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 128
epochs = 20

hist_mlp_1 = mlp_1.fit(x_train_flat, z_train, validation_data=(x_test_flat,z_test), epochs=epochs, batch_size=batch_size, verbose=2)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
#  - 2s - loss: 0.5327 - acc: 0.8051 - val_loss: 0.5243 - val_acc: 0.8114
# Epoch 2/20
#  - 1s - loss: 0.3764 - acc: 0.8606 - val_loss: 0.3931 - val_acc: 0.8587
# Epoch 3/20
#  - 1s - loss: 0.3365 - acc: 0.8763 - val_loss: 0.3542 - val_acc: 0.8727
# Epoch 4/20
#  - 1s - loss: 0.3107 - acc: 0.8847 - val_loss: 0.4148 - val_acc: 0.8644
# Epoch 5/20
#  - 1s - loss: 0.2943 - acc: 0.8911 - val_loss: 0.4824 - val_acc: 0.8595
# Epoch 6/20
#  - 1s - loss: 0.2810 - acc: 0.8957 - val_loss: 0.3720 - val_acc: 0.8779
# Epoch 7/20
#  - 1s - loss: 0.2701 - acc: 0.9006 - val_loss: 0.3507 - val_acc: 0.8823
# Epoch 8/20
#  - 1s - loss: 0.2622 - acc: 0.9033 - val_loss: 0.3624 - val_acc: 0.8836
# Epoch 9/20
#  - 1s - loss: 0.2508 - acc: 0.9073 - val_loss: 0.3766 - val_acc: 0.8843
# Epoch 10/20
#  - 1s - loss: 0.2440 - acc: 0.9093 - val_loss: 0.4321 - val_acc: 0.8623
# Epoch 11/20
#  - 1s - loss: 0.2370 - acc: 0.9114 - val_loss: 0.4169 - val_acc: 0.8730
# Epoch 12/20
#  - 1s - loss: 0.2317 - acc: 0.9156 - val_loss: 0.3969 - val_acc: 0.8839
# Epoch 13/20
#  - 1s - loss: 0.2263 - acc: 0.9156 - val_loss: 0.4067 - val_acc: 0.8840
# Epoch 14/20
#  - 1s - loss: 0.2226 - acc: 0.9191 - val_loss: 0.4293 - val_acc: 0.8800
# Epoch 15/20
#  - 1s - loss: 0.2177 - acc: 0.9202 - val_loss: 0.3934 - val_acc: 0.8864
# Epoch 16/20
#  - 1s - loss: 0.2112 - acc: 0.9216 - val_loss: 0.3717 - val_acc: 0.8931
# Epoch 17/20
#  - 1s - loss: 0.2064 - acc: 0.9248 - val_loss: 0.4937 - val_acc: 0.8746
# Epoch 18/20
#  - 1s - loss: 0.2062 - acc: 0.9256 - val_loss: 0.4205 - val_acc: 0.8853
# Epoch 19/20
#  - 1s - loss: 0.2009 - acc: 0.9270 - val_loss: 0.4225 - val_acc: 0.8874
# Epoch 20/20
#  - 1s - loss: 0.1964 - acc: 0.9281 - val_loss: 0.4744 - val_acc: 0.8790

# %% [markdown]
# #### 4) Define a generic function evaluate_model() able to:
# - plot the evolution of accuracy for both training and testing data with respect to the epochs
# - compute final test loss and accuracy.
#
# Use this function to assess the performance of the previously defined model.

# %%
def evaluate_model(model,history,x_eval,z_eval):
    
    # list all data in history
    print(history.history.keys())

    #Visualize history (loss vs epochs)
    plt.figure()
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')  
    plt.xlabel('epochs')
    plt.legend(['train','val'], loc='upper left')
    plt.show()
    
    score = model.evaluate(x_eval, z_eval, verbose=0)
    print('Test loss:', score[0])
    print('Test accuracy:', score[1])

# %%
evaluate_model(mlp_1,hist_mlp_1,x_test_flat,z_test)
# Out:
# ['acc', 'loss', 'val_acc', 'val_loss']
# ('Test loss:', 0.47436809285283088)
# ('Test accuracy:', 0.879)

# %% [markdown]
# Comments: generalisation error from 3~4 epochs

# %% [markdown]
# #### 5) Define a deeper multi-layer perceptron (MLP) architecture to outperform the previously obtained classification results.
# Use evaluate_model() to provide the evaluation and comment the performance.

# %%
mlp_2 = Sequential()

mlp_2.add(Dense(units=512, input_shape=(C*C,),activation="relu"))
mlp_2.add(Dense(units=512,activation="relu"))
mlp_2.add(Dense(units=512,activation="relu"))
mlp_2.add(Dense(units=512,activation="relu"))
mlp_2.add(Dense(10, activation="softmax"))

mlp_2.summary()

mlp_2.compile(RMSprop(), 'categorical_crossentropy', metrics=['accuracy'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_44 (Dense)             (None, 512)               401920
# _________________________________________________________________
# dense_45 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_46 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_47 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_48 (Dense)             (None, 10)                5130
# =================================================================
# Total params: 1,195,018
# Trainable params: 1,195,018
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 128
epochs = 20

hist_mlp_2 = mlp_2.fit(x_train_flat, z_train, validation_data=(x_test_flat,z_test), epochs=epochs, batch_size=batch_size, verbose=2)

evaluate_model(mlp_2,hist_mlp_2,x_test_flat,z_test)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
#  - 2s - loss: 0.5989 - acc: 0.7810 - val_loss: 0.5813 - val_acc: 0.7889
# Epoch 2/20
#  - 2s - loss: 0.4136 - acc: 0.8499 - val_loss: 0.5510 - val_acc: 0.8094
# Epoch 3/20
#  - 2s - loss: 0.3717 - acc: 0.8664 - val_loss: 0.4640 - val_acc: 0.8417
# Epoch 4/20
#  - 2s - loss: 0.3510 - acc: 0.8750 - val_loss: 0.3907 - val_acc: 0.8658
# Epoch 5/20
#  - 2s - loss: 0.3389 - acc: 0.8797 - val_loss: 0.4596 - val_acc: 0.8613
# Epoch 6/20
#  - 2s - loss: 0.3255 - acc: 0.8836 - val_loss: 0.3819 - val_acc: 0.8738
# Epoch 7/20
#  - 2s - loss: 0.3201 - acc: 0.8859 - val_loss: 0.4487 - val_acc: 0.8627
# Epoch 8/20
#  - 2s - loss: 0.3144 - acc: 0.8885 - val_loss: 0.4273 - val_acc: 0.8753
# Epoch 9/20
#  - 2s - loss: 0.3077 - acc: 0.8908 - val_loss: 0.4174 - val_acc: 0.8736
# Epoch 10/20
#  - 2s - loss: 0.2999 - acc: 0.8929 - val_loss: 0.4425 - val_acc: 0.8699
# Epoch 11/20
#  - 1s - loss: 0.2945 - acc: 0.8959 - val_loss: 0.4308 - val_acc: 0.8704
# Epoch 12/20
#  - 2s - loss: 0.2913 - acc: 0.8979 - val_loss: 0.4064 - val_acc: 0.8814
# Epoch 13/20
#  - 2s - loss: 0.2910 - acc: 0.8993 - val_loss: 0.4156 - val_acc: 0.8802
# Epoch 14/20
#  - 2s - loss: 0.2782 - acc: 0.9010 - val_loss: 0.4913 - val_acc: 0.8651
# Epoch 15/20
#  - 1s - loss: 0.2856 - acc: 0.9030 - val_loss: 0.4739 - val_acc: 0.8676
# Epoch 16/20
#  - 2s - loss: 0.2790 - acc: 0.9041 - val_loss: 0.6767 - val_acc: 0.8181
# Epoch 17/20
#  - 2s - loss: 0.2729 - acc: 0.9056 - val_loss: 0.4083 - val_acc: 0.8862
# Epoch 18/20
#  - 2s - loss: 0.2684 - acc: 0.9088 - val_loss: 0.4362 - val_acc: 0.8784
# Epoch 19/20
#  - 2s - loss: 0.2727 - acc: 0.9095 - val_loss: 0.4308 - val_acc: 0.8661
# Epoch 20/20
#  - 2s - loss: 0.2682 - acc: 0.9102 - val_loss: 0.4229 - val_acc: 0.8825
# ['acc', 'loss', 'val_acc', 'val_loss']
# ('Test loss:', 0.42290242074728013)
# ('Test accuracy:', 0.88249999999999995)

# %% [markdown]
# Conclusion: accuracy a bit better but not much.
# maybe the limit of MLP ?

# %% [markdown]
# ### Part 3 - Convolutional neural networks

# %% [markdown]
# ##### 6) Define a simple Keras convolutional neural network (CNN) architecture using Sequential API and containing the following layers : 1 convolution layer using Conv2D and 32 filters, 1 max-polling layer using MaxPooling2D, 2 dense layers using ReLU and softmax activations respectively. Use this model to get classification results (use evaluate_model() as previously) and compared them to MLP results.

# %%
# build 4D tensors
x_train_cnn = x_train.reshape(A, C, C, 1)
x_test_cnn = x_test.reshape(B, C, C, 1)

input_shape = (C, C, 1)

# %%
from keras.layers import Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K

# %%
cnn_1 = Sequential()

cnn_1.add(Conv2D(32, (3,3), activation="relu", input_shape = input_shape, padding="SAME"))
cnn_1.add(MaxPooling2D())
cnn_1.add(Flatten())
cnn_1.add(Dense(units=(C*C*32)/4,activation="relu"))
cnn_1.add(Dense(units=num_classes, activation="softmax"))

cnn_1.summary()

cnn_1.compile(RMSprop(), 'categorical_crossentropy', metrics=['accuracy'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 28, 28, 32)        320
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dense_57 (Dense)             (None, 6272)              39344256
# _________________________________________________________________
# dense_58 (Dense)             (None, 10)                62730
# =================================================================
# Total params: 39,407,306
# Trainable params: 39,407,306
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 128
epochs = 20

hist_cnn_1 = cnn_1.fit(x_train_cnn, z_train, validation_data=(x_test_cnn,z_test), epochs=epochs, batch_size=batch_size, verbose=2)
evaluate_model(cnn_1,hist_cnn_1,x_test_cnn,z_test)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
#  - 19s - loss: 0.4503 - acc: 0.8541 - val_loss: 0.4011 - val_acc: 0.8556
# Epoch 2/20
#  - 16s - loss: 0.2328 - acc: 0.9142 - val_loss: 0.2672 - val_acc: 0.9060
# Epoch 3/20
#  - 16s - loss: 0.1793 - acc: 0.9334 - val_loss: 0.2999 - val_acc: 0.8983
# Epoch 4/20
#  - 16s - loss: 0.1389 - acc: 0.9499 - val_loss: 0.3167 - val_acc: 0.9077
# Epoch 5/20
#  - 16s - loss: 0.1113 - acc: 0.9597 - val_loss: 0.2921 - val_acc: 0.9167
# Epoch 6/20
#  - 16s - loss: 0.0877 - acc: 0.9688 - val_loss: 0.3217 - val_acc: 0.9189
# Epoch 7/20
#  - 16s - loss: 0.0691 - acc: 0.9762 - val_loss: 0.3472 - val_acc: 0.9182
# Epoch 8/20
#  - 16s - loss: 0.0561 - acc: 0.9796 - val_loss: 0.3461 - val_acc: 0.9180
# Epoch 9/20
#  - 16s - loss: 0.0488 - acc: 0.9830 - val_loss: 0.3793 - val_acc: 0.9166
# Epoch 10/20
#  - 16s - loss: 0.0384 - acc: 0.9870 - val_loss: 0.4292 - val_acc: 0.9184
# Epoch 11/20
#  - 16s - loss: 0.0325 - acc: 0.9886 - val_loss: 0.4568 - val_acc: 0.9166
# Epoch 12/20
#  - 16s - loss: 0.0286 - acc: 0.9902 - val_loss: 0.4452 - val_acc: 0.9143
# Epoch 13/20
#  - 17s - loss: 0.0254 - acc: 0.9919 - val_loss: 0.4500 - val_acc: 0.9193
# Epoch 14/20
#  - 17s - loss: 0.0243 - acc: 0.9928 - val_loss: 0.4983 - val_acc: 0.9210
# Epoch 15/20
#  - 17s - loss: 0.0189 - acc: 0.9939 - val_loss: 0.5297 - val_acc: 0.9180
# Epoch 16/20
#  - 16s - loss: 0.0174 - acc: 0.9947 - val_loss: 0.5304 - val_acc: 0.9169
# Epoch 17/20
#  - 17s - loss: 0.0154 - acc: 0.9948 - val_loss: 0.5444 - val_acc: 0.9162
# Epoch 18/20
#  - 16s - loss: 0.0151 - acc: 0.9952 - val_loss: 0.5763 - val_acc: 0.9120
# Epoch 19/20
#  - 17s - loss: 0.0145 - acc: 0.9959 - val_loss: 0.6144 - val_acc: 0.9118
# Epoch 20/20
#  - 17s - loss: 0.0125 - acc: 0.9963 - val_loss: 0.6332 - val_acc: 0.9116
# ['acc', 'loss', 'val_acc', 'val_loss']
# ('Test loss:', 0.63322244270443917)
# ('Test accuracy:', 0.91159999999999997)

# %% [markdown]
# Comments: #todo

# %% [markdown]
# #### 7) As for MLP, define a deeper CNN architecture to outperform the previously obtained classification results. What are your conclusions?

# %%
cnn_2 = Sequential()
# cnn_2.add(...)
# to do 
# evaluate_model(...)

# %% [markdown]
# Comments: #todo

# %% [markdown]
# ### Part 4 - Visualize wrongly predictions

# %% [markdown]
# #### 8) Create a function visualize_wrongly_predictions() able to show wrong prediction for each class for a given model as input. Use this function for each of the 4 previouly trained models (2 MLP, 2 CNN).

# %%
# def visualize_wrongly_predictions(model,...):
    # to do

# %%
# visualize_wrongly_predictions(mlp_1,...)
# visualize_wrongly_predictions(mlp_2,...)

# %%
# visualize_wrongly_predictions(cnn_1,...)
# visualize_wrongly_predictions(cnn_2,...)

# %% [markdown]
# Comments: #todo

# %% [markdown]
# #### 9) Using the code given below, create a function visualize_confusion_matrix() able to display the confusion matrix  for a given model as input. Use this function for each of the 4 previouly trained models (2 MLP, 2 CNN). What is the most common confusion?

# %%
from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# def visualize_confusion_matrix(model, ...):
    # to do

# %%
# visualize_confusion_matrix(mlp_1, ...)
# visualize_confusion_matrix(mlp_2, ...)

# %%
# visualize_confusion_matrix(cnn_1, ...)
# visualize_confusion_matrix(cnn_2, ...)

# %% [markdown]
# Most common confusion: #todo
#
# Conclusion:

# %% [markdown]
# ### Part 5 - Data augmentation

# %% [markdown]
# #### 10) Based on the documentation (https://keras.io/preprocessing/image/), train one of your CNN architecture using data augmentation and conclude on the used of augmented data.

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rotation_range=8,
    width_shift_range=0.08,
    height_shift_range=0.08,
    shear_range=0.3, 
    zoom_range=0.08)

# to do

# %% [markdown]
# Comments: #todo

# %% [markdown]
# ### Part 6 - Transfer learning from VGG16 trained on ImageNet

# %% [markdown]
# Transfer learning, is a research problem in machine learning that focuses on storing knowledge gained while solving one problem and applying it to a different but related problem.
#
# In this part, you will do fine tuning on a pre-trained network. Fine-tuning consists in starting from a trained network, then re-training it on a new dataset using very small weight updates. To do so, you need to load a pre-trained model, add a dense classifier to compute the output, and then to freeze the weights of the pre-trained model (https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html).

# %% [markdown]
# #### 11) Exploit an architecture already trained on ImageNet (https://keras.io/applications) to improve the classification results on Fashion-MNIST.

# %%
from keras import applications
from skimage.transform import resize

# to do

# %%
# to do

# %% [markdown]
# Conclusion: #todo

# %% [markdown]
# #### 12) Challenge: the first 3 teams in terms of overall test accuracy results (whatever the methodology used) will obtain bonus points!

# %% [markdown]
# Best accuracy reached: #todo

# %% [markdown]
# Conclusions: #todo
